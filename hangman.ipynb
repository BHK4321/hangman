# %%
import json
import os
import requests
import random
import string
import secrets
import time
import re
import collections
import torch
import torch.nn as nn
import math
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
import copy
import numpy as np
from collections import defaultdict
from collections import Counter
from tqdm import tqdm
import re

# %%
class HangmanDataset1(Dataset):
    def __init__(self, words, max_word_length=45, reveal_ratio=0.5):
        self.words = [word.lower() for word in words if len(word) <= max_word_length]
        self.max_length = max_word_length
        self.reveal_ratio = reveal_ratio
        self.char_to_idx = {char: i+1 for i, char in enumerate(string.ascii_lowercase)}
        self.char_to_idx['_'] = 0  # blank
        self.char_to_idx['PAD'] = 27

    def __len__(self): return len(self.words) * 80

    def __getitem__(self, idx):
        word = self.words[idx % len(self.words)]
        reveal_count = int(len(word) * self.reveal_ratio)
        revealed = random.sample(range(len(word)), reveal_count) if reveal_count > 0 else []

        word_state = [0] * self.max_length
        for pos in revealed: word_state[pos] = self.char_to_idx[word[pos]]

        target_pos, target_chars, position_context, vowels = [], [], [0]*self.max_length, set('aeiou')
        for i in range(len(word)):
            if i not in revealed:
                ctx = 0
                if i > 0 and word_state[i-1] != 0: ctx += 1
                if i < len(word)-1 and word_state[i+1] != 0: ctx += 2
                if ctx:
                    target_pos.append(i)
                    target_chars.append(self.char_to_idx[word[i]])
                    position_context[i] = ctx

        count_blanks = word_state[:len(word)].count(0)
        blank_vowel_next = [0]*self.max_length
        for i in range(len(word)):
            if word_state[i] == 0:
                l = word[i-1] if i > 0 else 'x'
                r = word[i+1] if i < len(word)-1 else 'x'
                if l in vowels or r in vowels:
                    blank_vowel_next[i] = 1

        max_targets = 10
        while len(target_pos) < max_targets:
            target_pos.append(-1)
            target_chars.append(0)

        return {
            'word_state': torch.tensor(word_state, dtype=torch.long),
            'position_context': torch.tensor(position_context, dtype=torch.long),
            'target_positions': torch.tensor(target_pos[:max_targets], dtype=torch.long),
            'target_chars': torch.tensor(target_chars[:max_targets], dtype=torch.long),
            'word_length': torch.tensor(len(word), dtype=torch.long),
            'blank_count': torch.tensor(count_blanks, dtype=torch.long),
            'next_to_vowel': torch.tensor(blank_vowel_next, dtype=torch.float)
        }

class EnhancedHangmanModel1(nn.Module):
    def __init__(self, vocab_size=28, max_len=45, emb_dim=128, hidden_dim=1024, ablate={}):
        super().__init__()
        self.ablate = ablate
        self.char_emb = nn.Embedding(vocab_size, emb_dim)
        self.ctx_emb = nn.Embedding(4, 32)

        self.pattern_cnn = nn.Sequential(
            nn.Conv1d(emb_dim, 64, 3, padding=1), nn.ReLU(), nn.Dropout(0.2),
            nn.Conv1d(64, 64, 3, padding=1), nn.ReLU(), nn.Dropout(0.2)
        )

        self.encoder = nn.LSTM(emb_dim + 32, hidden_dim, bidirectional=True, batch_first=True)

        self.pos_prior_mlp = nn.Sequential(
            nn.Linear(1 + 1 + 64, 32), nn.ReLU(), nn.Dropout(0.2), nn.Linear(32, 26)
        )

        def decoder():
            return nn.Sequential(
                nn.Linear(hidden_dim*2 + 26, hidden_dim),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(hidden_dim, hidden_dim // 2),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(hidden_dim // 2, 26)
            )

        self.left_decoder = decoder()
        self.right_decoder = decoder()
        self.both_decoder = decoder()

    def forward(self, word_state, position_context, word_length, blank_count, next_to_vowel):
        B, L = word_state.size()
        emb = self.char_emb(word_state)
        cnn_feat = self.pattern_cnn(emb.transpose(1, 2)).transpose(1, 2)
        ctx = self.ctx_emb(position_context)
        encoded, _ = self.encoder(torch.cat([emb, ctx], -1))

        pos_scores = []
        for i in range(L):
            is_blank = (word_state[:, i] == 0).float().unsqueeze(1)
            bc = blank_count.unsqueeze(1).float() / L
            pos_input = torch.cat([is_blank, bc, cnn_feat[:, i, :]], -1)
            pos_scores.append(self.pos_prior_mlp(pos_input).unsqueeze(1))
        priors = torch.cat(pos_scores, 1)  # [B, L, 26]

        out = torch.zeros(B, L, 26, device=word_state.device)
        for i in range(L):
            h = encoded[:, i, :]
            ptype = position_context[:, i]
            inp = torch.cat([h, priors[:, i, :]], -1)
            out[ptype==1, i, :] = self.left_decoder(inp[ptype==1])
            out[ptype==2, i, :] = self.right_decoder(inp[ptype==2])
            out[ptype==3, i, :] = self.both_decoder(inp[ptype==3])

        return out

def build_lengthwise_frequencies(word_list):
    """Build a map from word length to letter frequency Counter."""
    length_freq = defaultdict(Counter)
    for word in word_list:
        word = word.lower()
        unique_letters = set(word)
        length_freq[len(word)].update(unique_letters)
    return length_freq

def get_best_first_guess(word_length, guessed_letters, length_freq):
    """
    Returns the best frequency-based first guess for a given word length,
    excluding already guessed letters.
    """
    if word_length not in length_freq:
        # fallback to global frequency
        total_counter = Counter()
        for counter in length_freq.values():
            total_counter += counter
        freq = total_counter
    else:
        freq = length_freq[word_length]

    sorted_letters = [letter for letter, _ in freq.most_common() if letter not in guessed_letters]
    return sorted_letters[0] if sorted_letters else None

def word_matches_pattern(word, pattern, wrong_letters):
    """Check if a word matches the current hangman pattern"""
    if len(word) != len(pattern):
        return False
    if pattern.count('_') == len(pattern):
        return True
    # Reject if it contains any wrong letters
    if any(letter in word for letter in wrong_letters):
        return False
    
    # Check position-by-position for pattern match
    for w_char, p_char in zip(word, pattern):
        if p_char != '_' and w_char != p_char:
            return False
        if p_char == '_' and w_char in wrong_letters:
            return False  # Prevent wrong letters in unknown positions
    
    return True


def get_dictionary_filtered_multipliers(word_pattern, wrong_letters, dictionary):
    """
    Filter dictionary based on current pattern and wrong letters,
    then calculate letter frequency penalties based on positional constraints
    around revealed substrings.
    """
            
    # Find matching words
    matching_words = []
    
    pattern_str = ''.join(word_pattern)
    for word in dictionary:
        if word_matches_pattern(word, word_pattern, wrong_letters):
            matching_words.append(word)
    multipliers = {letter: 0.9 for letter in string.ascii_lowercase}
    for letter in string.ascii_lowercase:
        for word in matching_words:
            for i in range(len(word)):
                if word[i] == letter and word_pattern[i] == '_':
                    multipliers[letter]=1.1
                    break
            if multipliers[letter] == 1.1:
                break
    return multipliers, len(matching_words), len(dictionary) - len(matching_words)
   
class HangmanSolver1:
    def __init__(self, word_list, length_freq, model_path="best_model1.pth"):
        self.model = EnhancedHangmanModel1()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model.to(self.device)
        self.model.eval()

        self.dictionary = word_list
        self.char_to_idx = {c: i+1 for i, c in enumerate(string.ascii_lowercase)}
        self.char_to_idx['_'] = 0
        self.idx_to_char = {v: k for k, v in self.char_to_idx.items() if v != 0}
        self.length_freq = length_freq

        # Dictionary-based RL multipliers
        self.dict_multipliers = {letter: 1.0 for letter in string.ascii_lowercase}
        
    def update_dict_multipliers(self, word_pattern, wrong_letters):
        """Update multipliers based on dictionary filtering"""
        multipliers, matching_count, eliminated_count = get_dictionary_filtered_multipliers(
            word_pattern, wrong_letters, self.dictionary
        )
        self.dict_multipliers = multipliers
        return matching_count, eliminated_count

    def predict_letter(self, word_state, guessed_letters=None):
        if guessed_letters is None:
            guessed_letters = set()
        wrong_letters = {ch for ch in guessed_letters if ch not in word_state and ch.isalpha()}
        if wrong_letters is None:
            wrong_letters = set()
        if ' ' in word_state:
            word_state = word_state.replace(' ', '')
        # Update dictionary-based multipliers
        word_pattern = list(word_state)
        matching_count, eliminated_count = self.update_dict_multipliers(word_pattern, wrong_letters)
        # Use best first guess based on frequency
        if word_state.count('_') == len(word_state):
            return get_best_first_guess(len(word_state), guessed_letters, self.length_freq)
        
        max_length = 45
        state_indices = []
        position_context = []
    
        for i, char in enumerate(word_state):
            if char == '_':
                state_indices.append(0)
                ctx = 0
                if i > 0 and word_state[i-1] != '_': ctx += 1
                if i < len(word_state)-1 and word_state[i+1] != '_': ctx += 2
                position_context.append(ctx)
            else:
                state_indices.append(self.char_to_idx.get(char, 27))
                position_context.append(0)
    
        while len(state_indices) < max_length:
            state_indices.append(27)
            position_context.append(0)
    
        word_tensor = torch.tensor([state_indices], dtype=torch.long).to(self.device)
        context_tensor = torch.tensor([position_context], dtype=torch.long).to(self.device)
        length_tensor = torch.tensor([len(word_state)], dtype=torch.long).to(self.device)
        blank_count_tensor = torch.tensor([word_state.count('_')], dtype=torch.long).to(self.device)
    
        blank_vowel_next = [0] * max_length
        for i in range(len(word_state)):
            if word_state[i] == '_':
                l = word_state[i-1] if i > 0 else 'x'
                r = word_state[i+1] if i < len(word_state)-1 else 'x'
                if l in 'aeiou' or r in 'aeiou':
                    blank_vowel_next[i] = 1
        blank_vowel_tensor = torch.tensor([blank_vowel_next], dtype=torch.float).to(self.device)
    
        with torch.no_grad():
            model_out = self.model(
                word_tensor, context_tensor, length_tensor,
                blank_count_tensor, blank_vowel_tensor
            )
        # print(self.dict_multipliers)
        # Apply dictionary-based multipliers
        dict_multipliers_tensor = torch.tensor(
            [self.dict_multipliers[chr(ord('a') + i)] for i in range(26)],
            device=self.device
        )
        
        best_predictions = []
        for i in range(len(word_state)):
            if word_state[i] == '_':
                # Apply dictionary multipliers to model predictions
                adjusted_logits = model_out[0, i, :]
                reveal_ratio = sum(1 for c in word_state if c != '_') / len(word_state)
                if reveal_ratio < 0.35:
                    adjusted_logits *= dict_multipliers_tensor
                
                probs = torch.softmax(adjusted_logits, dim=0)
                for j, prob in enumerate(probs):
                    letter = chr(ord('a') + j)
                    if letter not in guessed_letters:
                        best_predictions.append((letter, prob.item(), i))
    
        if best_predictions:
            best_predictions.sort(key=lambda x: x[1], reverse=True)
            return best_predictions[0][0]
    
        # Fallback to frequency-based guess
        available_letters = [c for c in string.ascii_lowercase if c not in guessed_letters]
        if available_letters:
            return available_letters[0]
        return None

def simulate_hangman_game(solver1, solver2, word, max_wrong=6, verbose=False):
    """Simulate a hangman game and return results"""
    true_word = word.lower()
    word_state = ['_'] * len(true_word)
    guessed_letters = set()
    wrong_letters = set()
    wrong_count = 0
    
    if verbose:
        print(f"Word: {true_word}")
        print(f"Initial state: {''.join(word_state)}")
    
    while '_' in word_state and wrong_count < max_wrong:
        # Get prediction
        reveal_ratio = len([c for c in word_state if c != '_']) / len(true_word)
        solver = solver1 if reveal_ratio > 0.65 else solver2
        guess = solver.predict_letter(''.join(word_state), guessed_letters)
        
        if guess is None or guess in guessed_letters:
            break
            
        guessed_letters.add(guess)
        
        # Check if guess is correct
        if guess in true_word:
            # Reveal all instances of the letter
            for i, char in enumerate(true_word):
                if char == guess:
                    word_state[i] = char
            if verbose:
                print(f"Correct guess '{guess}': {''.join(word_state)}")
        else:
            wrong_letters.add(guess)
            wrong_count += 1
            if verbose:
                print(f"Wrong guess '{guess}' ({wrong_count}/{max_wrong}): {''.join(word_state)}")
    
    success = '_' not in word_state
    if verbose:
        print(f"Game result: {'WIN' if success else 'LOSE'}")
        print(f"Final state: {''.join(word_state)}")
        print(f"Wrong guesses: {sorted(wrong_letters)}")
    
    return {
        'success': success,
        'word': true_word,
        'guesses': len(guessed_letters),
        'wrong_guesses': wrong_count,
        'final_state': ''.join(word_state)
    }

def train_model1(words, epochs=10, early_stopping_patience=5):
    print("Updated...")
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = EnhancedHangmanModel1()
    if torch.cuda.device_count() > 1:
        model = nn.DataParallel(model)
    model.to(device)

    opt = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    scheduler = ReduceLROnPlateau(opt, patience=2)
    loss_fn = nn.CrossEntropyLoss()

    best = float('inf')
    patience_counter = 0

    for ep in range(epochs):
        # Curriculum: reveal_ratio increases with epoch (starts hard, becomes easier)
        reveal_schedule = [0.93, 0.87, 0.80, 0.80, 0.73, 0.73, 0.67, 0.67, 0.67, 0.60, 0.60, 0.53, 0.53, 0.47, 0.47, 0.40, 0.40, 0.33, 0.33, 0.27]
        reveal_ratio = reveal_schedule[ep] if ep < len(reveal_schedule) else 0.20
        ds = HangmanDataset1(words, reveal_ratio=reveal_ratio)
        train_len = int(0.9 * len(ds))
        tr, val = random_split(ds, [train_len, len(ds)-train_len])
        dl = DataLoader(tr, shuffle=True, pin_memory=True, batch_size=256, num_workers=4)
        vl = DataLoader(val, pin_memory=True, batch_size=256, num_workers=4)

        print(f"\n--- Epoch {ep+1} | Reveal Ratio: {reveal_ratio:.2f} ---", flush=True)
        model.train()
        total_loss = 0
        batch_count = 0

        for i, batch in enumerate(tqdm(dl, desc="Training", ncols=100)):
            opt.zero_grad()
            out = model(batch['word_state'].to(device), batch['position_context'].to(device),
                        batch['word_length'].to(device), batch['blank_count'].to(device),
                        batch['next_to_vowel'].to(device))
            loss, count = 0, 0
            for b in range(out.size(0)):
                target_pos = batch['target_positions'][b].to(device)
                target_char = batch['target_chars'][b].to(device)
                for p, c in zip(target_pos, target_char):
                    if p >= 0 and c > 0:
                        loss += loss_fn(out[b, p], c-1)
                        count += 1
            if count > 0:
                loss = loss / count
                loss.backward()
                opt.step()
                total_loss += loss.item()
                batch_count += 1
            if i % 20 == 0:
                if isinstance(loss, torch.Tensor):
                    print(f"  Batch {i}/{len(dl)} | Loss: {loss.item():.4f}", flush=True)
                else:
                    print(f"  Batch {i}/{len(dl)} | Loss: N/A (no valid targets)", flush=True)

        train_loss = total_loss / batch_count if batch_count > 0 else 0
        model.eval()
        val_loss = 0
        val_batches = 0
        with torch.no_grad():
            for batch in tqdm(vl, desc="Validation", ncols=100):
                out = model(batch['word_state'].to(device), batch['position_context'].to(device),
                            batch['word_length'].to(device), batch['blank_count'].to(device),
                            batch['next_to_vowel'].to(device))
                loss, count = 0, 0
                for b in range(out.size(0)):
                    target_pos = batch['target_positions'][b].to(device)
                    target_char = batch['target_chars'][b].to(device)
                    for p, c in zip(target_pos, target_char):
                        if p >= 0 and c > 0:
                            loss += loss_fn(out[b, p], c-1)
                            count += 1
                if count > 0:
                    val_loss += loss.item() / count
                    val_batches += 1

        val_loss = val_loss / val_batches if val_batches > 0 else 0
        scheduler.step(val_loss)

        if val_loss < best:
            best = val_loss
            patience_counter = 0
            torch.save(model.module.state_dict() if isinstance(model, nn.DataParallel) else model.state_dict(), "best_model1.pth")
            print("✅ Model improved and saved.", flush=True)
        else:
            patience_counter += 1
            print(f"⚠️ No improvement. Patience: {patience_counter}/{early_stopping_patience}", flush=True)
            if patience_counter >= early_stopping_patience:
                print(f"🛑 Early stopping at epoch {ep+1}", flush=True)
                break

    return model

# %%
def clean_state_dict(state_dict):
    """Removes 'module.' prefix from multi-GPU trained models if present"""
    new_state_dict = {}
    for k, v in state_dict.items():
        if k.startswith('module.'):
            new_state_dict[k[7:]] = v
        else:
            new_state_dict[k] = v
    return new_state_dict

# %%
dictionary = open("words_250000_train.txt").read().splitlines()
random.shuffle(dictionary)
word_list = dictionary
length_freq = build_lengthwise_frequencies(word_list)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model1 = EnhancedHangmanModel1()
if torch.cuda.device_count() > 1:
    model1 = nn.DataParallel(model1)

model1 = model1.to(device)
model_path = "best_model1.pth"
checkpoint = torch.load(model_path, map_location=device, weights_only=True)
cleaned_checkpoint0 = clean_state_dict(checkpoint)
if isinstance(model1, nn.DataParallel):
    model1.module.load_state_dict(cleaned_checkpoint0)
else:
    model1.load_state_dict(cleaned_checkpoint0)

solver1 = HangmanSolver1(word_list, length_freq=length_freq, model_path=model_path)
solver1.model = model1

#------------------------------------
model2 = EnhancedHangmanModel1()
if torch.cuda.device_count() > 1:
    model2 = nn.DataParallel(model2)

model2 = model2.to(device)
model_path0 = "best_model2.pth"
checkpoint0 = torch.load(model_path0, map_location=device, weights_only=True)
cleaned_checkpoint1 = clean_state_dict(checkpoint0)
if isinstance(model2, nn.DataParallel):
    model2.module.load_state_dict(cleaned_checkpoint1)
else:
    model2.load_state_dict(cleaned_checkpoint1)

solver2 = HangmanSolver1(word_list,  length_freq=length_freq, model_path=model_path0)
solver2.model = model2

# Test on specific word
result = simulate_hangman_game(solver1, solver2, "example", verbose=True)
# Out:
# Word: example
# Initial state: _______
# Correct guess 'e': e_____e
# Wrong guess 'h' (1/6): e_____e
# Wrong guess 'n' (2/6): e_____e
# Wrong guess 'r' (3/6): e_____e
# Correct guess 'l': e____le
# Correct guess 'a': e_a__le
# Correct guess 'm': e_am_le
# Wrong guess 'b' (4/6): e_am_le
# Correct guess 'p': e_ample
# Wrong guess 'c' (5/6): e_ample
# Correct guess 'x': example
# Game result: WIN
# Final state: example
# Wrong guesses: ['b', 'c', 'h', 'n', 'r']

# %%
solver1.model.eval()
solver2.model.eval()
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []

        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()

        self.current_dictionary = []

    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def guess(self, word):
        total_letters = sum(1 for c in word if c != ' ')
        revealed_letters = sum(1 for c in word if c != '_' and c != ' ')
        reveal_ratio = revealed_letters / total_letters if total_letters > 0 else 0
        # if reveal_ratio < 0.40:
        #     return solver3.predict_letter(word, self.guessed_letters)
        if reveal_ratio > 0.65:
            return solver1.predict_letter(word, self.guessed_letters)
        else:
            return solver2.predict_letter(word, self.guessed_letters)
        #return enhanced_solver.rl_wrapper.predict_letter_with_rl(word, set(self.guessed_letters))

    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary

    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
        solver1.dict_multipliers = {letter: 1.0 for letter in string.ascii_lowercase}
        solver2.dict_multipliers = {letter: 1.0 for letter in string.ascii_lowercase}
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)

                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))

                try:
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e

                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"

    def my_status(self):
        return self.request("/my_status", {})

    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result

class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %%
api = HangmanAPI(access_token="", timeout=2000)

# %%
for i in range(100):
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = (total_practice_successes)/(total_practice_runs)
    print('accuracy = %.3f%%' % (100 * practice_success_rate))

    time.sleep(0.5)
# Out:
# Successfully start a new game! Game ID: 64707a5450d1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ r _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ a _ _ r _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ a t _ r _ _ t '}
# Guessing letter: s
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e _ _ s a t _ r _ s t '}
# Guessing letter: i
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e _ _ s a t i r i s t '}
# Guessing letter: m
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 5, 'word': 's e _ _ s a t i r i s t '}
# Guessing letter: n
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 4, 'word': 's e _ _ s a t i r i s t '}
# Guessing letter: l
# Sever response: {'game_id': '64707a5450d1', 'status': 'ongoing', 'tries_remains': 4, 'word': 's e l _ s a t i r i s t '}
# Guessing letter: f
# Sever response: {'game_id': '64707a5450d1', 'status': 'success', 'tries_remains': 4, 'word': 's e l f s a t i r i s t '}
# Successfully finished game: 64707a5450d1
# accuracy = 100.000%
# Successfully start a new game! Game ID: 1e9cd63264a6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ e '}
# Guessing letter: h
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ r _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ r _ _ e '}
# Guessing letter: o
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ r _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ r _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ r i _ e '}
# Guessing letter: b
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ r i _ e '}
# Guessing letter: m
# Sever response: {'game_id': '1e9cd63264a6', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ r i _ e '}
# Failed game: 1e9cd63264a6. Because of: # of tries exceeded!
# accuracy = 50.000%
# Successfully start a new game! Game ID: 4a9dc32b52ce. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e '}
# Guessing letter: h
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ l _ _ _ _ l e '}
# Guessing letter: a
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ l _ _ _ _ l e '}
# Guessing letter: o
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ l o _ _ _ l e '}
# Guessing letter: n
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ l o _ _ _ l e '}
# Guessing letter: i
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i l o _ _ _ l e '}
# Guessing letter: b
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i l o _ _ _ l e '}
# Guessing letter: m
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ i l o _ _ _ l e '}
# Guessing letter: k
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'ongoing', 'tries_remains': 1, 'word': 'k i l o _ _ _ l e '}
# Guessing letter: s
# Sever response: {'game_id': '4a9dc32b52ce', 'status': 'failed', 'tries_remains': 0, 'word': 'k i l o _ _ _ l e '}
# Failed game: 4a9dc32b52ce. Because of: # of tries exceeded!
# accuracy = 33.333%
# Successfully start a new game! Game ID: f02bc7e661fd. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ i _ _ _ _ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ i _ n _ _ _ _ _ i _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ i a n _ _ a _ _ i _ _ '}
# Guessing letter: m
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 6, 'word': 'm a _ i a n _ _ a _ _ i _ _ '}
# Guessing letter: h
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 5, 'word': 'm a _ i a n _ _ a _ _ i _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 5, 'word': 'm a _ i a n o _ a _ _ i _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 5, 'word': 'm a r i a n o _ a _ r i _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 5, 'word': 'm a r i a n o _ a _ r i s _ '}
# Guessing letter: t
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 5, 'word': 'm a r i a n o _ a t r i s t '}
# Guessing letter: p
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 4, 'word': 'm a r i a n o _ a t r i s t '}
# Guessing letter: c
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 3, 'word': 'm a r i a n o _ a t r i s t '}
# Guessing letter: b
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 2, 'word': 'm a r i a n o _ a t r i s t '}
# Guessing letter: g
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'ongoing', 'tries_remains': 1, 'word': 'm a r i a n o _ a t r i s t '}
# Guessing letter: k
# Sever response: {'game_id': 'f02bc7e661fd', 'status': 'failed', 'tries_remains': 0, 'word': 'm a r i a n o _ a t r i s t '}
# Failed game: f02bc7e661fd. Because of: # of tries exceeded!
# accuracy = 25.000%
# Successfully start a new game! Game ID: c74efe4f843e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r a _ '}
# Guessing letter: n
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e r a _ '}
# Guessing letter: t
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e r a _ '}
# Guessing letter: l
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ l e r a _ '}
# Guessing letter: o
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ l e r a _ '}
# Guessing letter: i
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ l e r a _ '}
# Guessing letter: u
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ l e r a _ '}
# Guessing letter: c
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ c l e r a _ '}
# Guessing letter: s
# Sever response: {'game_id': 'c74efe4f843e', 'status': 'success', 'tries_remains': 1, 'word': 's c l e r a s '}
# Successfully finished game: c74efe4f843e
# accuracy = 40.000%
# Successfully start a new game! Game ID: 1d4f7a697a5b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ i _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ i _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r _ _ i _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r _ _ i _ _ '}
# Guessing letter: u
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r u _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r u _ i t _ '}
# Guessing letter: c
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c r u _ i t _ '}
# Guessing letter: y
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c r u _ i t y '}
# Guessing letter: m
# Sever response: {'game_id': '1d4f7a697a5b', 'status': 'failed', 'tries_remains': 0, 'word': 'c r u _ i t y '}
# Failed game: 1d4f7a697a5b. Because of: # of tries exceeded!
# accuracy = 33.333%
# Successfully start a new game! Game ID: 42590363b058. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ e _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ e _ _ _ r _ '}
# Guessing letter: a
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ e a _ _ e _ _ _ r _ '}
# Guessing letter: n
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ e a _ _ e n _ _ r _ '}
# Guessing letter: t
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ e a _ t e n _ _ r _ '}
# Guessing letter: l
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ e a l t e n _ _ r _ '}
# Guessing letter: d
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ e a l t e n _ _ r _ '}
# Guessing letter: b
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ e a l t e n b _ r _ '}
# Guessing letter: o
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ e a l t e n b _ r _ '}
# Guessing letter: h
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ e a l t e n b _ r _ '}
# Guessing letter: u
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ e a l t e n b u r _ '}
# Guessing letter: g
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ e a l t e n b u r g '}
# Guessing letter: c
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ e a l t e n b u r g '}
# Guessing letter: m
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ e a l t e n b u r g '}
# Guessing letter: s
# Sever response: {'game_id': '42590363b058', 'status': 'ongoing', 'tries_remains': 1, 'word': 's a _ e a l t e n b u r g '}
# Guessing letter: v
# Sever response: {'game_id': '42590363b058', 'status': 'failed', 'tries_remains': 0, 'word': 's a _ e a l t e n b u r g '}
# Failed game: 42590363b058. Because of: # of tries exceeded!
# accuracy = 28.571%
# Successfully start a new game! Game ID: 2d6233f68e26. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ i _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ n _ _ i _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ n _ _ i _ _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 4, 'word': 'h _ _ n _ _ i _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 4, 'word': 'h _ _ n o _ i _ _ _ '}
# Guessing letter: m
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 3, 'word': 'h _ _ n o _ i _ _ _ '}
# Guessing letter: y
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 3, 'word': 'h y _ n o _ i _ _ _ '}
# Guessing letter: p
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 3, 'word': 'h y p n o _ i _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 2, 'word': 'h y p n o _ i _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h y p n o _ i _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '2d6233f68e26', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h y p n o _ i s _ s '}
# Guessing letter: t
# Sever response: {'game_id': '2d6233f68e26', 'status': 'success', 'tries_remains': 1, 'word': 'h y p n o t i s t s '}
# Successfully finished game: 2d6233f68e26
# accuracy = 37.500%
# Successfully start a new game! Game ID: a78f010b2fee. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: h
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 6, 'word': 'h _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h _ _ _ _ e _ '}
# Guessing letter: o
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h o _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 4, 'word': 'h o _ _ _ e _ '}
# Guessing letter: l
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 4, 'word': 'h o _ _ l e _ '}
# Guessing letter: m
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 3, 'word': 'h o _ _ l e _ '}
# Guessing letter: n
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 2, 'word': 'h o _ _ l e _ '}
# Guessing letter: i
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h o _ _ l e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h o _ _ l e s '}
# Guessing letter: b
# Sever response: {'game_id': 'a78f010b2fee', 'status': 'success', 'tries_remains': 1, 'word': 'h o b b l e s '}
# Successfully finished game: a78f010b2fee
# accuracy = 44.444%
# Successfully start a new game! Game ID: 1602d0991d80. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ _ _ _ '}
# Guessing letter: m
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a s _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a s _ _ _ t '}
# Guessing letter: h
# Sever response: {'game_id': '1602d0991d80', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a s h _ _ t '}
# Guessing letter: o
# Sever response: {'game_id': '1602d0991d80', 'status': 'failed', 'tries_remains': 0, 'word': 'a s h _ _ t '}
# Failed game: 1602d0991d80. Because of: # of tries exceeded!
# accuracy = 40.000%
# Successfully start a new game! Game ID: 11ccbb3104bf. # of tries remaining: 6. Word: _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '11ccbb3104bf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '11ccbb3104bf', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '11ccbb3104bf', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '11ccbb3104bf', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '11ccbb3104bf', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '11ccbb3104bf', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ '}
# Failed game: 11ccbb3104bf. Because of: # of tries exceeded!
# accuracy = 36.364%
# Successfully start a new game! Game ID: 29cb5c1a5a06. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ r _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r _ e _ '}
# Guessing letter: o
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ r _ e _ '}
# Guessing letter: u
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ r _ e _ '}
# Guessing letter: n
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ r _ e n '}
# Guessing letter: d
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd _ r _ e n '}
# Guessing letter: l
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd _ r _ e n '}
# Guessing letter: s
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd _ r _ e n '}
# Guessing letter: t
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd _ r t e n '}
# Guessing letter: i
# Sever response: {'game_id': '29cb5c1a5a06', 'status': 'success', 'tries_remains': 1, 'word': 'd i r t e n '}
# Successfully finished game: 29cb5c1a5a06
# accuracy = 41.667%
# Successfully start a new game! Game ID: e6e3608c6afd. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'e6e3608c6afd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'e6e3608c6afd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ '}
# Guessing letter: m
# Sever response: {'game_id': 'e6e3608c6afd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ '}
# Guessing letter: b
# Sever response: {'game_id': 'e6e3608c6afd', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'e6e3608c6afd', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'e6e3608c6afd', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ _ '}
# Guessing letter: k
# Sever response: {'game_id': 'e6e3608c6afd', 'status': 'failed', 'tries_remains': 0, 'word': '_ a _ _ '}
# Failed game: e6e3608c6afd. Because of: # of tries exceeded!
# accuracy = 38.462%
# Successfully start a new game! Game ID: 5a2f6c8ad05d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '5a2f6c8ad05d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '5a2f6c8ad05d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '5a2f6c8ad05d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '5a2f6c8ad05d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '5a2f6c8ad05d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ _ s _ '}
# Guessing letter: h
# Sever response: {'game_id': '5a2f6c8ad05d', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ _ _ s _ '}
# Guessing letter: t
# Sever response: {'game_id': '5a2f6c8ad05d', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ _ _ s _ '}
# Failed game: 5a2f6c8ad05d. Because of: # of tries exceeded!
# accuracy = 35.714%
# Successfully start a new game! Game ID: c6bd8997456e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ r _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ r _ _ a _ _ e '}
# Guessing letter: h
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ r _ _ a _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ _ r _ _ a _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ _ r i _ a _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n _ e _ _ r i _ a _ _ e '}
# Guessing letter: d
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n d e _ _ r i _ a _ _ e '}
# Guessing letter: u
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u n d e _ _ r i _ a _ _ e '}
# Guessing letter: v
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'u n d e _ _ r i _ a _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'u n d e _ _ r i _ a _ l e '}
# Guessing letter: b
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'u n d e _ _ r i b a b l e '}
# Guessing letter: s
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'u n d e s _ r i b a b l e '}
# Guessing letter: c
# Sever response: {'game_id': 'c6bd8997456e', 'status': 'success', 'tries_remains': 3, 'word': 'u n d e s c r i b a b l e '}
# Successfully finished game: c6bd8997456e
# accuracy = 40.000%
# Successfully start a new game! Game ID: 8aea2b1392ce. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ '}
# Guessing letter: h
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ h _ e _ '}
# Guessing letter: c
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ c h _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a _ c h _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r a _ c h _ e _ '}
# Guessing letter: n
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r a n c h _ e _ '}
# Guessing letter: b
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 6, 'word': 'b r a n c h _ e _ '}
# Guessing letter: i
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 5, 'word': 'b r a n c h _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 4, 'word': 'b r a n c h _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b r a n c h _ e _ '}
# Guessing letter: w
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 2, 'word': 'b r a n c h _ e _ '}
# Guessing letter: l
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'ongoing', 'tries_remains': 2, 'word': 'b r a n c h l e _ '}
# Guessing letter: t
# Sever response: {'game_id': '8aea2b1392ce', 'status': 'success', 'tries_remains': 2, 'word': 'b r a n c h l e t '}
# Successfully finished game: 8aea2b1392ce
# accuracy = 43.750%
# Successfully start a new game! Game ID: 3812cdb93c7a. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ e _ '}
# Guessing letter: h
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ e _ '}
# Guessing letter: n
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e n _ _ e _ '}
# Guessing letter: t
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e n _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e n _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e n _ r e _ '}
# Guessing letter: s
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e n _ r e s '}
# Guessing letter: c
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e n _ r e s '}
# Guessing letter: g
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n _ r e s '}
# Guessing letter: f
# Sever response: {'game_id': '3812cdb93c7a', 'status': 'failed', 'tries_remains': 0, 'word': 'e n _ r e s '}
# Failed game: 3812cdb93c7a. Because of: # of tries exceeded!
# accuracy = 41.176%
# Successfully start a new game! Game ID: 585d8ca3d660. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '585d8ca3d660', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '585d8ca3d660', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r _ e r _ '}
# Guessing letter: a
# Sever response: {'game_id': '585d8ca3d660', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e r _ e r _ '}
# Guessing letter: i
# Sever response: {'game_id': '585d8ca3d660', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e r _ e r _ '}
# Guessing letter: b
# Sever response: {'game_id': '585d8ca3d660', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e r _ e r _ '}
# Guessing letter: o
# Sever response: {'game_id': '585d8ca3d660', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e r _ e r _ '}
# Guessing letter: h
# Sever response: {'game_id': '585d8ca3d660', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e r _ e r _ '}
# Guessing letter: m
# Sever response: {'game_id': '585d8ca3d660', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e r m e r _ '}
# Guessing letter: k
# Sever response: {'game_id': '585d8ca3d660', 'status': 'failed', 'tries_remains': 0, 'word': '_ e r m e r _ '}
# Failed game: 585d8ca3d660. Because of: # of tries exceeded!
# accuracy = 38.889%
# Successfully start a new game! Game ID: 4086a3dc5215. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ _ _ _ i _ _ _ i _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ _ _ _ i _ _ _ i n _ _ _ '}
# Guessing letter: g
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ _ _ _ i _ _ _ i n g _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ _ _ _ i _ _ _ i n g _ _ '}
# Guessing letter: u
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ _ _ _ i _ _ _ i n g _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ _ _ _ i _ _ _ i n g l _ '}
# Guessing letter: e
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i _ _ _ _ i _ _ _ i n g l _ '}
# Guessing letter: a
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i _ _ a _ i _ _ _ i n g l _ '}
# Guessing letter: m
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i _ _ a _ i _ _ _ i n g l _ '}
# Guessing letter: y
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i _ _ a _ i _ _ y i n g l y '}
# Guessing letter: s
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i s s a _ i s _ y i n g l y '}
# Guessing letter: t
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i s s a t i s _ y i n g l y '}
# Guessing letter: f
# Sever response: {'game_id': '4086a3dc5215', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i s s a t i s f y i n g l y '}
# Guessing letter: d
# Sever response: {'game_id': '4086a3dc5215', 'status': 'success', 'tries_remains': 2, 'word': 'd i s s a t i s f y i n g l y '}
# Successfully finished game: 4086a3dc5215
# accuracy = 42.105%
# Successfully start a new game! Game ID: 943b3b57329f. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '943b3b57329f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '943b3b57329f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '943b3b57329f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '943b3b57329f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ e _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '943b3b57329f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ e n _ '}
# Guessing letter: t
# Sever response: {'game_id': '943b3b57329f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ t e n t '}
# Guessing letter: s
# Sever response: {'game_id': '943b3b57329f', 'status': 'success', 'tries_remains': 3, 'word': 's t e n t '}
# Successfully finished game: 943b3b57329f
# accuracy = 45.000%
# Successfully start a new game! Game ID: 8b888ff65602. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '8b888ff65602', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '8b888ff65602', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '8b888ff65602', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ n _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '8b888ff65602', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e a n _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '8b888ff65602', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e a n _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '8b888ff65602', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ e a n _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '8b888ff65602', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ e a n _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '8b888ff65602', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ _ e a n _ _ '}
# Guessing letter: g
# Sever response: {'game_id': '8b888ff65602', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ _ e a n _ _ '}
# Failed game: 8b888ff65602. Because of: # of tries exceeded!
# accuracy = 42.857%
# Successfully start a new game! Game ID: 26569a4faba9. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ n _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ n _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ n i _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e c _ n i c _ '}
# Guessing letter: h
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e c h n i c _ '}
# Guessing letter: t
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 4, 'word': 't e c h n i c _ '}
# Guessing letter: o
# Sever response: {'game_id': '26569a4faba9', 'status': 'ongoing', 'tries_remains': 3, 'word': 't e c h n i c _ '}
# Guessing letter: s
# Sever response: {'game_id': '26569a4faba9', 'status': 'success', 'tries_remains': 3, 'word': 't e c h n i c s '}
# Successfully finished game: 26569a4faba9
# accuracy = 45.455%
# Successfully start a new game! Game ID: 5587fe32c9d3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ e '}
# Guessing letter: h
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ _ l e '}
# Guessing letter: a
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ a _ l e '}
# Guessing letter: b
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ a b l e '}
# Guessing letter: n
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ n a b l e '}
# Guessing letter: i
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ n a b l e '}
# Guessing letter: m
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ _ n a b l e '}
# Guessing letter: s
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ _ n a b l e '}
# Guessing letter: d
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd e _ _ n a b l e '}
# Guessing letter: o
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd e _ o n a b l e '}
# Guessing letter: t
# Sever response: {'game_id': '5587fe32c9d3', 'status': 'success', 'tries_remains': 1, 'word': 'd e t o n a b l e '}
# Successfully finished game: 5587fe32c9d3
# accuracy = 47.826%
# Successfully start a new game! Game ID: 5af998367e0d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ i _ _ _ i _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ i _ _ _ i _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r _ _ _ _ _ r _ i _ _ _ i _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r e _ _ _ _ r _ i _ _ _ i _ _ '}
# Guessing letter: p
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p r e _ _ _ _ r _ i _ _ _ i _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p r e _ _ _ _ r _ i _ a _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p r e _ _ _ _ r _ i n a _ i n _ '}
# Guessing letter: g
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p r e _ _ _ _ r _ i n a _ i n g '}
# Guessing letter: t
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p r e _ _ _ _ r _ i n a t i n g '}
# Guessing letter: l
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ _ _ _ r _ i n a t i n g '}
# Guessing letter: d
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ _ _ _ r d i n a t i n g '}
# Guessing letter: o
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ _ _ o r d i n a t i n g '}
# Guessing letter: c
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p r e _ _ _ o r d i n a t i n g '}
# Guessing letter: s
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p r e s _ _ o r d i n a t i n g '}
# Guessing letter: u
# Sever response: {'game_id': '5af998367e0d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p r e s u _ o r d i n a t i n g '}
# Guessing letter: b
# Sever response: {'game_id': '5af998367e0d', 'status': 'success', 'tries_remains': 3, 'word': 'p r e s u b o r d i n a t i n g '}
# Successfully finished game: 5af998367e0d
# accuracy = 50.000%
# Successfully start a new game! Game ID: a773f0870117. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i _ _ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i n _ _ _ n _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ _ a i n _ _ _ n _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ a i n _ _ _ n _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ a i n t _ _ n _ _ _ '}
# Guessing letter: h
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ a i n t _ _ n _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ a i n t e _ n e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ a i n t e _ n e s s '}
# Guessing letter: l
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ _ a i n t e _ n e s s '}
# Guessing letter: m
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ _ a i n t e _ n e s s '}
# Guessing letter: c
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a c _ _ a i n t e _ n e s s '}
# Guessing letter: d
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a c _ _ a i n t e d n e s s '}
# Guessing letter: p
# Sever response: {'game_id': 'a773f0870117', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a c _ _ a i n t e d n e s s '}
# Guessing letter: k
# Sever response: {'game_id': 'a773f0870117', 'status': 'failed', 'tries_remains': 0, 'word': 'a c _ _ a i n t e d n e s s '}
# Failed game: a773f0870117. Because of: # of tries exceeded!
# accuracy = 48.000%
# Successfully start a new game! Game ID: 19c9b9ae49a3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ e _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ n e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ n e _ a '}
# Guessing letter: i
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ n e _ a '}
# Guessing letter: m
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ n e m a '}
# Guessing letter: b
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ _ n e m a '}
# Guessing letter: l
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ _ n e m a '}
# Guessing letter: c
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a c _ _ n e m a '}
# Guessing letter: k
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a c _ _ n e m a '}
# Guessing letter: h
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a c h _ n e m a '}
# Guessing letter: s
# Sever response: {'game_id': '19c9b9ae49a3', 'status': 'failed', 'tries_remains': 0, 'word': '_ a c h _ n e m a '}
# Failed game: 19c9b9ae49a3. Because of: # of tries exceeded!
# accuracy = 46.154%
# Successfully start a new game! Game ID: e14175be6803. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ i _ '}
# Guessing letter: h
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h _ _ _ _ _ _ _ _ _ _ h _ _ _ h _ _ i _ '}
# Guessing letter: c
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h _ _ _ _ _ _ _ _ _ _ h _ _ _ h _ _ i c '}
# Guessing letter: e
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h e _ _ _ e _ _ _ _ _ h _ _ _ h _ _ i c '}
# Guessing letter: o
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h e _ o _ e _ o _ o _ h o _ _ h o _ i c '}
# Guessing letter: p
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h e _ o _ e _ o _ o p h o _ p h o _ i c '}
# Guessing letter: s
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h e _ o s e _ o _ o p h o s p h o _ i c '}
# Guessing letter: m
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h e _ o s e m o _ o p h o s p h o _ i c '}
# Guessing letter: n
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h e _ o s e m o n o p h o s p h o _ i c '}
# Guessing letter: r
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 5, 'word': 'h e _ o s e m o n o p h o s p h o r i c '}
# Guessing letter: l
# Sever response: {'game_id': 'e14175be6803', 'status': 'ongoing', 'tries_remains': 4, 'word': 'h e _ o s e m o n o p h o s p h o r i c '}
# Guessing letter: x
# Sever response: {'game_id': 'e14175be6803', 'status': 'success', 'tries_remains': 4, 'word': 'h e x o s e m o n o p h o s p h o r i c '}
# Successfully finished game: e14175be6803
# accuracy = 48.148%
# Successfully start a new game! Game ID: bff9cb6efeed. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ _ _ _ _ _ _ _ n _ '}
# Guessing letter: i
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ _ _ i _ i _ i n _ '}
# Guessing letter: g
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ _ _ i _ i _ i n g '}
# Guessing letter: m
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e m _ _ i _ i _ i n g '}
# Guessing letter: l
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e m _ _ i l i _ i n g '}
# Guessing letter: t
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r e m _ _ i l i _ i n g '}
# Guessing letter: z
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r e m _ _ i l i z i n g '}
# Guessing letter: u
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r e m _ _ i l i z i n g '}
# Guessing letter: v
# Sever response: {'game_id': 'bff9cb6efeed', 'status': 'failed', 'tries_remains': 0, 'word': 'r e m _ _ i l i z i n g '}
# ...
# Guessing letter: c
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n _ o _ _ _ i _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 5, 'word': 'n o n _ o _ _ r i _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 4, 'word': 'n o n _ o _ _ r i _ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 4, 'word': 'n o n _ o _ _ r i _ _ _ _ e '}
# Guessing letter: h
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n _ o _ _ r i _ _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n _ o l _ r i _ _ _ l e '}
# Guessing letter: b
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n _ o l _ r i _ _ b l e '}
# Guessing letter: a
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n _ o l a r i _ a b l e '}
# Guessing letter: p
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n p o l a r i _ a b l e '}
# Guessing letter: s
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n o n p o l a r i _ a b l e '}
# Guessing letter: z
# Sever response: {'game_id': '2bfca7f4d2a7', 'status': 'success', 'tries_remains': 2, 'word': 'n o n p o l a r i z a b l e '}
# Successfully finished game: 2bfca7f4d2a7
# accuracy = 47.253%
# Successfully start a new game! Game ID: e93f48659f38. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r _ _ e _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r a _ e _ _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r a _ e _ _ _ _ '}
# Guessing letter: v
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ e _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r a _ e _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r a _ e _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r a _ e _ _ _ s '}
# Guessing letter: u
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r a _ e _ _ u s '}
# Guessing letter: o
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r a _ e _ o u s '}
# Guessing letter: m
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r a _ e m o u s '}
# Guessing letter: d
# Sever response: {'game_id': 'e93f48659f38', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r a _ e m o u s '}
# Guessing letter: c
# Sever response: {'game_id': 'e93f48659f38', 'status': 'success', 'tries_remains': 1, 'word': 'r a c e m o u s '}
# Successfully finished game: e93f48659f38
# accuracy = 47.826%
# Successfully start a new game! Game ID: 16a2f6d6b980. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ '}
# Guessing letter: b
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ _ _ '}
# Guessing letter: m
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e m _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e m _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e m i _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e m i _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '16a2f6d6b980', 'status': 'failed', 'tries_remains': 0, 'word': '_ e m i _ _ '}
# Failed game: 16a2f6d6b980. Because of: # of tries exceeded!
# accuracy = 47.312%
# Successfully start a new game! Game ID: e5fdb00b4207. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'e5fdb00b4207', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ a '}
# Guessing letter: m
# Sever response: {'game_id': 'e5fdb00b4207', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ a '}
# Guessing letter: r
# Sever response: {'game_id': 'e5fdb00b4207', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ a '}
# Guessing letter: b
# Sever response: {'game_id': 'e5fdb00b4207', 'status': 'ongoing', 'tries_remains': 4, 'word': 'b a _ _ a '}
# Guessing letter: h
# Sever response: {'game_id': 'e5fdb00b4207', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b a _ _ a '}
# Guessing letter: n
# Sever response: {'game_id': 'e5fdb00b4207', 'status': 'ongoing', 'tries_remains': 2, 'word': 'b a _ _ a '}
# Guessing letter: k
# Sever response: {'game_id': 'e5fdb00b4207', 'status': 'ongoing', 'tries_remains': 1, 'word': 'b a _ _ a '}
# Guessing letter: l
# Sever response: {'game_id': 'e5fdb00b4207', 'status': 'failed', 'tries_remains': 0, 'word': 'b a _ _ a '}
# Failed game: e5fdb00b4207. Because of: # of tries exceeded!
# accuracy = 46.809%
# Successfully start a new game! Game ID: 16bb2bfdfd62. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e n _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e n _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e n _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ e n _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l _ _ e n _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l _ _ e n _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l _ _ e n _ o '}
# Guessing letter: u
# Sever response: {'game_id': '16bb2bfdfd62', 'status': 'failed', 'tries_remains': 0, 'word': 'l _ _ e n _ o '}
# Failed game: 16bb2bfdfd62. Because of: # of tries exceeded!
# accuracy = 46.316%
# Successfully start a new game! Game ID: 63bf457f5f69. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ i _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ i _ _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ l _ _ _ l i _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ l _ _ _ l i _ _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ l _ _ _ l i _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ l o o _ l i _ _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ l o o d l i _ _ _ _ '}
# Guessing letter: b
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ l o o d l i _ _ _ _ '}
# Guessing letter: g
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ l o o d l i g _ _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ l o o d l i g h _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ l o o d l i g h t _ '}
# Guessing letter: s
# Sever response: {'game_id': '63bf457f5f69', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ l o o d l i g h t s '}
# Guessing letter: f
# Sever response: {'game_id': '63bf457f5f69', 'status': 'success', 'tries_remains': 1, 'word': 'f l o o d l i g h t s '}
# Successfully finished game: 63bf457f5f69
# accuracy = 46.875%
# Successfully start a new game! Game ID: 308bf8f0f6aa. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '308bf8f0f6aa', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ e _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': '308bf8f0f6aa', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ e _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '308bf8f0f6aa', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e _ e _ _ e '}
# Guessing letter: h
# Sever response: {'game_id': '308bf8f0f6aa', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ e _ e _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '308bf8f0f6aa', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ e _ e _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '308bf8f0f6aa', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ e t e _ _ e '}
# Guessing letter: m
# Sever response: {'game_id': '308bf8f0f6aa', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ _ e t e _ _ e '}
# Guessing letter: p
# Sever response: {'game_id': '308bf8f0f6aa', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ _ e t e _ _ e '}
# Failed game: 308bf8f0f6aa. Because of: # of tries exceeded!
# accuracy = 46.392%
# Successfully start a new game! Game ID: 1cbda4bc2fdc. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ a _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ a _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n _ n _ _ a _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n o n _ _ a _ _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n o n _ _ a _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n o n _ _ a _ l _ '}
# Guessing letter: b
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n o n _ _ a b l _ '}
# Guessing letter: y
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n o n _ _ a b l y '}
# Guessing letter: s
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n o n s _ a b l y '}
# Guessing letter: t
# Sever response: {'game_id': '1cbda4bc2fdc', 'status': 'success', 'tries_remains': 2, 'word': 'n o n s t a b l y '}
# Successfully finished game: 1cbda4bc2fdc
# accuracy = 46.939%
# Successfully start a new game! Game ID: 952ad00ce89c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r r _ _ _ _ _ r '}
# Guessing letter: h
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e r r _ _ _ _ _ r '}
# Guessing letter: a
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e r r _ _ a _ _ r '}
# Guessing letter: t
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ t e r r _ _ a t _ r '}
# Guessing letter: n
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n t e r r _ _ a t _ r '}
# Guessing letter: i
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t e r r _ _ a t _ r '}
# Guessing letter: m
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n t e r r _ _ a t _ r '}
# Guessing letter: o
# Sever response: {'game_id': '952ad00ce89c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n t e r r o _ a t o r '}
# Guessing letter: g
# Sever response: {'game_id': '952ad00ce89c', 'status': 'success', 'tries_remains': 4, 'word': 'i n t e r r o g a t o r '}
# Successfully finished game: 952ad00ce89c
# accuracy = 47.475%
# Successfully start a new game! Game ID: ec2fefcf1a7a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ e _ '}
# Guessing letter: h
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ h _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ h a _ a _ e _ '}
# Guessing letter: c
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ h a _ a _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ h a _ a _ e _ '}
# Guessing letter: l
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ h a _ a _ e _ '}
# Guessing letter: m
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'm e _ h a _ a _ e _ '}
# Guessing letter: t
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'm e t h a _ a t e _ '}
# Guessing letter: n
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'm e t h a n a t e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'ongoing', 'tries_remains': 2, 'word': 'm e t h a n a t e _ '}
# Guessing letter: d
# Sever response: {'game_id': 'ec2fefcf1a7a', 'status': 'success', 'tries_remains': 2, 'word': 'm e t h a n a t e d '}
# Successfully finished game: ec2fefcf1a7a
# accuracy = 48.000%
